# %% [markdown]
# # Sales

# %%
import pandas as pd
df = pd.read_csv('Dummy Marketing Sales Data.csv')

# %%
df.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0   NaN   6.566231      2.907983       Mega   54.732757
# 1  13.0   0.237765      2.409567       Mega         NaN
# 2  41.0  15.886446           NaN       Mega  150.177829
# 3  83.0        NaN      6.922304        NaN  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %%
df.tail()
# Out:
#         TV      Radio  Social Media Influencer       Sales
# 4567  26.0   4.472360      0.717090      Micro   94.685866
# 4568  71.0  20.610685      6.545573       Nano  249.101915
# 4569  44.0  19.800072      5.096192      Micro  163.631457
# 4570  71.0  17.534640      1.940873      Macro  253.610411
# 4571  42.0  15.966688      5.046548      Micro  148.202414

# %%
df.describe()
# Out:
#                 TV        Radio  Social Media        Sales
# count  4561.000000  4567.000000   4565.000000  4565.000000
# mean     54.075203    18.155788      3.324046   192.498538
# std      26.121835     9.679159      2.212904    93.118286
# min      10.000000     0.000684      0.000031    31.199409
# 25%      32.000000    10.524925      1.527642   112.345307
# 50%      53.000000    17.855848      3.055758   189.498468
# 75%      77.000000    25.647904      4.807659   272.536784
# max     100.000000    48.871161     13.981662   364.079751

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV            4561 non-null   float64
#  1   Radio         4567 non-null   float64
#  2   Social Media  4565 non-null   float64
#  3   Influencer    4571 non-null   object
#  4   Sales         4565 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 178.7+ KB

# %%
df['TV']
# Out:
# 0        NaN
# 1       13.0
# 2       41.0
# 3       83.0
# 4       15.0
#         ...
# 4567    26.0
# 4568    71.0
# 4569    44.0
# 4570    71.0
# 4571    42.0
# Name: TV, Length: 4572, dtype: float64

# %%
print(df['TV']>39)
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 4567    False
# 4568     True
# 4569     True
# 4570     True
# 4571     True
# Name: TV, Length: 4572, dtype: bool

# %%
df.sort_values('TV',ascending=False)
# Out:
#          TV      Radio  Social Media Influencer       Sales
# 1752  100.0  33.151808      5.473668       Nano  352.031653
# 2972  100.0  36.072074      7.602360      Macro  354.449558
# 3840  100.0  36.761586      6.258341      Micro  356.441290
# 3420  100.0  37.711032      8.096591       Nano  355.643703
# 2511  100.0  37.146667      6.341597       Nano  355.109391
# ...     ...        ...           ...        ...         ...
# 119     NaN  30.470485      6.806919      Micro  336.818690
# 141     NaN   9.164464      1.096681      Macro   65.259189
# 163     NaN  38.118424      6.676611      Micro  328.555184
# 183     NaN   1.287060      0.396179      Macro   56.545293
# 210     NaN  17.007075      5.199635      Macro  208.816382
#
# [4572 rows x 5 columns]

# %%
df.isnull()
# Out:
#          TV  Radio  Social Media  Influencer  Sales
# 0      True  False         False       False  False
# 1     False  False         False       False   True
# 2     False  False          True       False  False
# 3     False   True         False        True  False
# 4     False  False         False       False  False
# ...     ...    ...           ...         ...    ...
# 4567  False  False         False       False  False
# 4568  False  False         False       False  False
# 4569  False  False         False       False  False
# 4570  False  False         False       False  False
# 4571  False  False         False       False  False
#
# [4572 rows x 5 columns]

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
for d in df:
    if d == 'Social Media':
        continue
    print(d)
# Out:
# TV
# Radio
# Influencer
# Sales

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
x=df["TV"]
y=df["Radio"]
plt.plot(x,y)

# %%
plt.scatter(x,y,color="red",marker='x')

# %%
df.fillna('0')
# Out:
#         TV      Radio Social Media Influencer       Sales
# 0        0   6.566231     2.907983       Mega   54.732757
# 1     13.0   0.237765     2.409567       Mega           0
# 2     41.0  15.886446            0       Mega  150.177829
# 3     83.0          0     6.922304          0   298.24634
# 4     15.0   8.437408     1.405998      Micro   56.594181
# ...    ...        ...          ...        ...         ...
# 4567  26.0    4.47236      0.71709      Micro   94.685866
# 4568  71.0  20.610685     6.545573       Nano  249.101915
# 4569  44.0  19.800072     5.096192      Micro  163.631457
# 4570  71.0   17.53464     1.940873      Macro  253.610411
# 4571  42.0  15.966688     5.046548      Micro  148.202414
#
# [4572 rows x 5 columns]

# %%
a=df['New_Sales']=df['Sales']*2

# %%
print(a)
# Out:
# 0       109.465514
# 1              NaN
# 2       300.355658
# 3       596.492680
# 4       113.188362
#            ...
# 4567    189.371731
# 4568    498.203831
# 4569    327.262915
# 4570    507.220823
# 4571    296.404828
# Name: Sales, Length: 4572, dtype: float64

# %%
df
# Out:
#         TV      Radio  Social Media Influencer       Sales   New_Sales
# 0      NaN   6.566231      2.907983       Mega   54.732757  109.465514
# 1     13.0   0.237765      2.409567       Mega         NaN         NaN
# 2     41.0  15.886446           NaN       Mega  150.177829  300.355658
# 3     83.0        NaN      6.922304        NaN  298.246340  596.492680
# 4     15.0   8.437408      1.405998      Micro   56.594181  113.188362
# ...    ...        ...           ...        ...         ...         ...
# 4567  26.0   4.472360      0.717090      Micro   94.685866  189.371731
# 4568  71.0  20.610685      6.545573       Nano  249.101915  498.203831
# 4569  44.0  19.800072      5.096192      Micro  163.631457  327.262915
# 4570  71.0  17.534640      1.940873      Macro  253.610411  507.220823
# 4571  42.0  15.966688      5.046548      Micro  148.202414  296.404828
#
# [4572 rows x 6 columns]

# %%
df["TV"].shape
# Out:
# (4572,)

# %%
df["TV"].head()
# Out:
# 0     NaN
# 1    13.0
# 2    41.0
# 3    83.0
# 4    15.0
# Name: TV, dtype: float64
